# %%
import requests

# %%
# Define headers
headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:140.0) Gecko/20100101 Firefox/140.0",
    "Accept": "*/*",
    "Accept-Language": "en-GB,en;q=0.5",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "X-Requested-With": "XMLHttpRequest",
    "Origin": "https://dzm.burblesoft.com",
    "Referer": "https://dzm.burblesoft.com/jmp",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "DNT": "1",
    "TE": "trailers"
}

# Define cookies
cookies = {
    "burblesoft": "7l030sh9u4df6rjpl810cmf8pb50lqo9"
}

# Define POST data
data = {
    "aircraft": "0",
    "columns": "4",
    "display_tandem": "1",
    "display_student": "1",
    "display_sport": "1",
    "display_menu": "1",
    "font_size": "0",
    "action": "getLoads",
    "dz_id": "531",
    "date_format": "d/m/Y",
    "acl_application": "Burble DZM"
}

# Send the POST request
response = requests.post(
    url="https://dzm.burblesoft.com/ajax_dzm2_frontend_jumpermanifestpublic",
    headers=headers,
    cookies=cookies,
    data=data
)

response.text
# Out:
# '{"queries":6,"loads":[{"id":"245242","name":"G-FOXP 6","status":"Building","is_no_time":"1","aircraft_id":"9431","expected_take_off":"1754655120","stop_at":"0","loading_gate_id":0,"landing_zone_id":0,"dzso_id":0,"gca_id":0,"lm_id":6453044,"reserve_slots":2,"max_slots":"15","private_slots":"2","public_slots":"13","is_turning":"1","is_fueling":"0","aircraft_name":"","caculate_expected_take_off":"1754655120","time_left":4,"groups":[[{"id":"6003902","jump":"TEAM","name":"Lee Clift","tribe":"","is_public":"1","is_private":"0","transaction_type_id":"1","type":"Sport Jumper","option_name":"","formation_type_id":"0","rig_id":"0","team_id":"131112","sale_id":"2200992","team_name":"AXIS-4","formation_type_name":"","rig_name":"","handycam_jump":"","group_number":"AXIS-4-5"}],[{"id":"6003782","jump":"TEAM","name":"Vincent Adams","tribe":"","is_public":"1","is_private":"0","transaction_type_id":"1","type":"Sport Jumper","option_name":"","formation_type_id":"0","rig_id":"0","team_id":"131112","sa
# ...
